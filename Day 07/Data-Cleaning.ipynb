# %%
import pandas as pd

# Read Excel file
df = pd.read_csv("Titanic-Dataset - C.csv")

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Titanic-Dataset - C.csv')
print(df.shape)
print("---------------------------------------")
print(df.info())
print("---------------------------------------")
print(df.isnull().sum())
print("---------------------------------------")
print(df.duplicated().sum())
# Out:
# (891, 12)
# ---------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB
# None
# ---------------------------------------
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ---------------------------------------
# 0

# %%
Filling Missing Ages:

# %%
df['Age'] = df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))

# %%
Cabin 1-recorded 0-notrecorded:

# %%
df['Has_Cabin'] = df['Cabin'].notna().astype(int)
df['Deck'] = df['Cabin'].str[0].fillna('Unknown')
df.drop(columns=['Cabin'], inplace=True)

# %%
Drop low-value rows:

# %%
df['Title'] = df['Name'].str.extract(r',\s*([^\.]+)\.')
df.drop(columns=['PassengerId', 'Name', 'Ticket'], inplace=True)

# %%
Embarked column

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
print(df.head())        
print("---------------------------------------")
print(df.isnull().sum()) 
print("---------------------------------------")
print(df.shape)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Has_Cabin  \
# 0         0       3    male  22.0      1      0   7.2500        S          0
# 1         1       1  female  38.0      1      0  71.2833        C          1
# 2         1       3  female  26.0      0      0   7.9250        S          0
# 3         1       1  female  35.0      1      0  53.1000        S          1
# 4         0       3    male  35.0      0      0   8.0500        S          0
#
#       Deck Title
# 0  Unknown    Mr
# 1        C   Mrs
# 2  Unknown  Miss
# 3        C   Mrs
# 4  Unknown    Mr
# ---------------------------------------
# Survived     0
# Pclass       0
# Sex          0
# Age          0
# SibSp        0
# Parch        0
# Fare         0
# Embarked     0
# Has_Cabin    0
# Deck         0
# Title        0
# dtype: int64
# ---------------------------------------
# (891, 11)

# %%
df.to_excel('Titanic_cleaned.xlsx', index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Uswa Khalil\elexoft ml\Day 7

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Data-Cleaning.ipynb', 'Titanic-Dataset - C.csv', 'Titanic_cleaned.xlsx']
